# %% [markdown]
# # Job description

# %% [markdown]
# ## Read the Job Description  pdf

# %%
import fitz  

def extract_text_from_pdf(pdf_path):
    doc = fitz.open(pdf_path)
    full_text = ""
    
    for page in doc:
        full_text += page.get_text()

    doc.close()
    return full_text

# Example usage
pdf_path = "job_descriptions.pdf"  
job_description_text = extract_text_from_pdf(pdf_path)

print(job_description_text)
# Out:
# 1. Information Technology (IT) Specialist
# Job Title: Information Technology (IT) Specialist
# Job Summary: Seeking a skilled IT Specialist to manage and support our organization's computer
# systems, software, and network infrastructure. The ideal candidate will have a strong technical
# background and excellent problem-solving skills.
# Key Responsibilities:
# Install, configure, and maintain software and hardware systems.
# Provide technical support and troubleshoot IT-related issues.
# Monitor system performance and ensure network availability.
# Implement cybersecurity best practices and ensure data protection.
# Qualifications:
# Bachelor's degree in Information Technology, Computer Science, or related field.
# Proficiency in operating systems (Windows, Linux) and networking protocols.
# Experience with cloud platforms (e.g., AWS, Azure) is a plus.
# Skills:
# Strong troubleshooting and communication skills.
# Ability to work independently and as part of a team.
# 2. Business Development Manager
# Job Title: Business Development Manager
# Job Summary: We are looking for a proactive Business Development Manager to identify new
# business opportunities, build client relationships, and drive company growth.
# Key Responsibilities:
# Develop and implement growth strategies.
# Identify and pursue new business opportunities.
# Build and maintain client relationships.
# Collaborate with marketing and product teams.
# Qualifications:
# Bachelor's degree in Business Administration, Marketing, or related field.
# Proven experience in business development or sales.
# Skills:
# Excellent communication and negotiation skills.
# Strong analytical and strategic thinking abilities.
# 3. Advocate (Lawyer)
# Job Title: Advocate (Lawyer)
# Job Summary: Seeking a qualified Advocate to represent clients in legal proceedings, provide
# legal advice, and draft legal documents.
# Key Responsibilities:
# Represent clients in court and legal proceedings.
# Provide legal counsel and advice.
# Draft and review legal documents.
# Conduct legal research.
# Qualifications:
# Bachelor's degree in Law.
# Valid license to practice law.
# Skills:
# Strong analytical and research skills.
# Excellent oral and written communication abilities.
# 4. Chef
# Job Title: Chef
# Job Summary: Looking for an experienced Chef to oversee kitchen operations, develop menus,
# and ensure high-quality food preparation.
# Key Responsibilities:
# Plan and create menus.
# Supervise kitchen staff.
# Ensure food quality and presentation.
# Maintain kitchen hygiene and safety standards.
# Qualifications:
# Culinary degree or equivalent experience.
# Proven experience as a Chef.
# Skills:
# Creativity and attention to detail.
# Strong leadership and organizational skills.
# 5. Engineer
# Job Title: Engineer
# Job Summary: Seeking a qualified Engineer to design, develop, and implement engineering
# solutions for various projects.
# Key Responsibilities:
# Design and develop engineering projects.
# Conduct research and analysis.
# Collaborate with cross-functional teams.
# Ensure compliance with safety and quality standards.
# Qualifications:
# Bachelor's degree in Engineering.
# Relevant engineering certifications.
# Skills:
# Strong problem-solving and analytical skills.
# Proficiency in engineering software and tools.
# 6. Accountant
# Job Title: Accountant
# Job Summary: We are looking for a detail-oriented Accountant to manage financial records,
# prepare reports, and ensure compliance with financial regulations.
# Key Responsibilities:
# Prepare and examine financial records.
# Ensure accuracy and compliance with regulations.
# Manage budgets and financial planning.
# Conduct audits and financial analysis.
# Qualifications:
# Bachelor's degree in Accounting or Finance.
# CPA certification is a plus.
# Skills:
# Proficiency in accounting software.
# Strong analytical and numerical skills.
# 7. Finance
# Job Title: Finance Analyst
# Job Summary: Seeking a Finance Analyst to assess financial data, prepare reports, and provide
# insights to support decision-making.
# Key Responsibilities:
# Analyze financial statements and data.
# Prepare financial reports and forecasts.
# Monitor financial performance.
# Provide recommendations for financial improvements.
# Qualifications:
# Bachelor's degree in Finance, Economics, or related field.
# Experience in financial analysis.
# Skills:
# Strong analytical and problem-solving skills.
# Proficiency in financial modeling and Excel.
# 8. Fitness
# Job Title: Fitness Trainer
# Job Summary: Looking for a certified Fitness Trainer to develop and implement fitness programs,
# guide clients, and promote healthy lifestyles.
# Key Responsibilities:
# Design personalized fitness programs.
# Instruct and motivate clients.
# Monitor progress and adjust programs as needed.
# Ensure safety during workouts.
# Qualifications:
# Certification in fitness training.
# Experience in personal training.
# Skills:
# Excellent interpersonal and motivational skills.
# Knowledge of fitness and nutrition principles.
# 9. Aviation
# Job Title: Aviation Technician
# Job Summary: Seeking an Aviation Technician to perform maintenance and repairs on aircraft to
# ensure safety and compliance.
# Key Responsibilities:
# Inspect and repair aircraft systems.
# Perform routine maintenance checks.
# Document maintenance activities.
# Ensure compliance with aviation regulations.
# Qualifications:
# Certification in aviation maintenance.
# Experience in aircraft maintenance.
# Skills:
# Attention to detail and technical proficiency.
# Strong problem-solving skills.
# 10. Sales
# Job Title: Sales Executive
# Job Summary: We are looking for a dynamic Sales Executive to drive sales, build client
# relationships, and achieve revenue targets.
# Key Responsibilities:
# Identify and pursue sales opportunities.
# Develop and maintain client relationships.
# Present products and services to clients.
# Achieve sales targets and objectives.
# Qualifications:
# Bachelor's degree in Business, Marketing, or related field.
# Proven sales experience.
# Skills:
# Excellent communication and negotiation skills.
# Ability to work independently and in a team.
# 11. Banking Professional
# Job Title: Banking Professional
# Job Summary: Seeking a detail-oriented Banking Professional to manage client accounts, process
# transactions, and provide financial guidance to customers.
# Key Responsibilities:
# Open and close customer accounts.
# Process deposits, withdrawals, and payments.
# Authorize and evaluate overdrafts and loans.
# Recommend banking services and products to clients.
# Qualifications:
# Bachelor's degree in Finance, Accounting, or related field.
# Experience in banking or financial services.
# Skills:
# Strong numerical and analytical skills.
# Excellent customer service and communication abilities.
# 12. Healthcare Administrator
# Job Title: Healthcare Administrator
# Job Summary: Looking for a Healthcare Administrator to oversee medical facility operations,
# ensuring efficient and effective delivery of healthcare services.
# Key Responsibilities:
# Manage daily operations of healthcare facilities.
# Coordinate between departments and staff.
# Ensure compliance with healthcare regulations.
# Develop and implement policies and procedures.
# Qualifications:
# Bachelor's degree in Healthcare Administration or related field.
# Experience in healthcare management.
# Skills:
# Strong leadership and organizational skills.
# Knowledge of healthcare laws and regulations.
# 13. Consultant
# Job Title: Consultant
# Job Summary: Seeking a Consultant to provide expert advice and solutions to improve business
# performance and efficiency.
# Key Responsibilities:
# Analyze organizational challenges and opportunities.
# Develop strategic plans and recommendations.
# Collaborate with clients to implement solutions.
# Monitor progress and adjust strategies as needed.
# Qualifications:
# Bachelor's degree in Business, Management, or related field.
# Proven experience in consulting or advisory roles.
# Skills:
# Strong analytical and problem-solving abilities.
# Excellent communication and interpersonal skills.
# 14. Construction Worker
# Job Title: Construction Worker
# Job Summary: Looking for a Construction Worker to perform various tasks on construction sites,
# ensuring projects are completed safely and efficiently.
# Key Responsibilities:
# Assist with building and demolition tasks.
# Operate construction equipment and tools.
# Follow safety protocols and guidelines.
# Collaborate with team members and supervisors.
# Qualifications:
# High school diploma or equivalent.
# Experience in construction or related fields.
# Skills:
# Physical stamina and strength.
# Knowledge of construction methods and materials.
# 15. Public Relations Specialist
# Job Title: Public Relations Specialist
# Job Summary: Seeking a Public Relations Specialist to manage and enhance the public image of
# our organization through strategic communication.
# Key Responsibilities:
# Develop and implement PR strategies.
# Write and distribute press releases and media content.
# Maintain relationships with media outlets.
# Monitor public opinion and manage crisis communication.
# Qualifications:
# Bachelor's degree in Public Relations, Communications, or related field.
# Experience in PR or media relations.
# Skills:
# Excellent written and verbal communication skills.
# Ability to manage multiple projects and deadlines.
# 16. Human Resources Manager
# Job Title: Human Resources Manager
# Job Summary: Looking for a Human Resources Manager to oversee HR functions, including
# recruitment, employee relations, and compliance with labor laws.
# Key Responsibilities:
# Manage hiring processes and onboarding.
# Develop HR policies and procedures.
# Address employee concerns and conflicts.
# Ensure compliance with employment regulations.
# Qualifications:
# Bachelor's degree in Human Resources or related field.
# Experience in HR management.
# Skills:
# Strong leadership and decision-making abilities.
# Knowledge of HR software and systems.
# 17. Designer
# Job Title: Designer
# Job Summary: Seeking a creative Designer to develop visual concepts and designs for various
# projects, ensuring alignment with brand identity.
# Key Responsibilities:
# Create designs for digital and print media.
# Collaborate with clients and team members.
# Present design concepts and revisions.
# Stay updated on design trends and tools.
# Qualifications:
# Bachelor's degree in Design, Fine Arts, or related field.
# Proficiency in design software (e.g., Adobe Creative Suite).
# Skills:
# Strong artistic and creative abilities.
# Attention to detail and aesthetic sensibility.
# 18. Artist
# Job Title: Artist
# Job Summary: Looking for an Artist to produce original artworks for various mediums,
# contributing to the creative vision of our projects.
# Key Responsibilities:
# Create artworks using different materials and techniques.
# Collaborate with clients and creative teams.
# Present and exhibit artworks.
# Continuously develop artistic skills.
# Qualifications:
# Bachelor's degree in Fine Arts or related field.
# Portfolio showcasing artistic works.
# Skills:
# Creativity and originality.
# Proficiency in various art mediums.
# 19. Teacher
# Job Title: Teacher
# Job Summary: Seeking a dedicated Teacher to educate and inspire students, fostering a positive
# and engaging learning environment.
# Key Responsibilities:
# Develop and deliver lesson plans.
# Assess student progress and provide feedback.
# Manage classroom behavior and dynamics.
# Collaborate with colleagues and parents.
# Qualifications:
# Bachelor's degree in Education or subject-specific field.
# Teaching certification or license.
# Skills:
# Strong communication and instructional skills.
# Patience and adaptability.
# 20. Apparel Designer
# Job Title: Apparel Designer
# Job Summary: Looking for an Apparel Designer to conceptualize and create clothing designs that
# align with current fashion trends and brand identity.
# Key Responsibilities:
# Develop sketches and prototypes for garments.
# Select fabrics and materials.
# Collaborate with production teams.
# Monitor market trends and consumer preferences.
# Qualifications:
# Bachelor's degree in Fashion Design or related field.
# Experience in apparel design.
# Skills:
# Creativity and fashion sense.
# Proficiency in design software and tools.
# 21. Digital Media Specialist
# Job Title: Digital Media Specialist
# Job Summary: Seeking a creative Digital Media Specialist to develop and manage digital content
# across various platforms, enhancing our online presence and engagement.
# Key Responsibilities:
# Create and manage digital content for websites, social media, and email campaigns.
# Develop and implement digital marketing strategies.
# Analyze performance metrics and optimize content accordingly.
# Collaborate with design and marketing teams to align content with brand guidelines.
# Qualifications:
# Bachelor's degree in Marketing, Communications, or related field.
# Experience with digital marketing tools and platforms.
# Skills:
# Proficiency in content management systems and analytics tools.
# Strong writing and editing skills.
# 22. Agricultural Worker
# Job Title: Agricultural Worker
# Job Summary: Looking for a dedicated Agricultural Worker to assist in crop cultivation and
# livestock care, ensuring efficient farm operations.
# Key Responsibilities:
# Plant, cultivate, and harvest crops.
# Feed and care for livestock.
# Operate and maintain farm machinery.
# Monitor crop and animal health.
# Qualifications:
# High school diploma or equivalent.
# Experience in farming or related activities.
# Skills:
# Physical stamina and strength.
# Knowledge of agricultural practices and machinery.
# 23. Automotive Technician
# Job Title: Automotive Technician
# Job Summary: Seeking a skilled Automotive Technician to diagnose, repair, and maintain vehicles,
# ensuring optimal performance and safety.
# Key Responsibilities:
# Perform routine maintenance and repairs on vehicles.
# Diagnose mechanical and electrical issues.
# Test vehicle systems and components.
# Maintain accurate records of services performed.
# Qualifications:
# Certification from a vocational school or completion of apprenticeship.
# Valid driver's license.
# Skills:
# Proficiency with diagnostic tools and equipment.
# Strong problem-solving abilities.
# 24. BPO (Business Process Outsourcing) Associate
# Job Title: BPO Associate
# Job Summary: Looking for a BPO Associate to handle customer interactions and support services,
# ensuring client satisfaction and efficient operations.
# Key Responsibilities:
# Manage inbound and outbound customer calls.
# Provide product and service information.
# Resolve customer complaints and issues.
# Document customer interactions and transactions.
# Qualifications:
# High school diploma or equivalent.
# Experience in customer service or call center environment.
# Skills:
# Excellent communication and interpersonal skills.
# Ability to handle multiple tasks efficiently.

# %% [markdown]
# ## Convert it to JSON Formate

# %%
import re

def parse_job_descriptions(text):
    # Split based on numbered job headers (e.g., 1. ..., 2. ...)
    job_splits = re.split(r'\n\d+\.\s+', text.strip())[0:]  # Skip the first empty element
    jobs = []

    for job_text in job_splits:
        # Extract each field using regex
        job_title = re.search(r'Job Title:\s*(.+)', job_text)
        summary = re.search(r'Job Summary:\s*(.+?)(?=Key Responsibilities:)', job_text, re.DOTALL)
        responsibilities = re.search(r'Key Responsibilities:\s*(.+?)(?=Qualifications:)', job_text, re.DOTALL)
        qualifications = re.search(r'Qualifications:\s*(.+?)(?=Skills:)', job_text, re.DOTALL)
        skills = re.search(r'Skills:\s*(.+)', job_text, re.DOTALL)

        job_dict = {
            "Job_Title": job_title.group(1).strip() if job_title else None,
            "Job_Summary": summary.group(1).strip() if summary else None,
            "Key_Responsibilities": responsibilities.group(1).strip() if responsibilities else None,
            "Qualifications": qualifications.group(1).strip() if qualifications else None,
            "Skills": skills.group(1).strip() if skills else None,
        }

        jobs.append(job_dict)

    return jobs

# %%
import json as Json

job_data = parse_job_descriptions(job_description_text)
print(Json.dumps(job_data, indent=2))
# Out:
# [
#   {
#     "Job_Title": "Information Technology (IT) Specialist",
#     "Job_Summary": "Seeking a skilled IT Specialist to manage and support our organization's computer\nsystems, software, and network infrastructure. The ideal candidate will have a strong technical\nbackground and excellent problem-solving skills.",
#     "Key_Responsibilities": "Install, configure, and maintain software and hardware systems.\nProvide technical support and troubleshoot IT-related issues.\nMonitor system performance and ensure network availability.\nImplement cybersecurity best practices and ensure data protection.",
#     "Qualifications": "Bachelor's degree in Information Technology, Computer Science, or related field.\nProficiency in operating systems (Windows, Linux) and networking protocols.\nExperience with cloud platforms (e.g., AWS, Azure) is a plus.",
#     "Skills": "Strong troubleshooting and communication skills.\nAbility to work independently and as part of a team."
#   },
#   {
#     "Job_Title": "Business Development Manager",
#     "Job_Summary": "We are looking for a proactive Business Development Manager to identify new\nbusiness opportunities, build client relationships, and drive company growth.",
#     "Key_Responsibilities": "Develop and implement growth strategies.\nIdentify and pursue new business opportunities.\nBuild and maintain client relationships.\nCollaborate with marketing and product teams.",
#     "Qualifications": "Bachelor's degree in Business Administration, Marketing, or related field.\nProven experience in business development or sales.",
#     "Skills": "Excellent communication and negotiation skills.\nStrong analytical and strategic thinking abilities."
#   },
#   {
#     "Job_Title": "Advocate (Lawyer)",
#     "Job_Summary": "Seeking a qualified Advocate to represent clients in legal proceedings, provide\nlegal advice, and draft legal documents.",
#     "Key_Responsibilities": "Represent clients in court and legal proceedings.\nProvide legal counsel and advice.\nDraft and review legal documents.\nConduct legal research.",
#     "Qualifications": "Bachelor's degree in Law.\nValid license to practice law.",
#     "Skills": "Strong analytical and research skills.\nExcellent oral and written communication abilities."
#   },
#   {
#     "Job_Title": "Chef",
#     "Job_Summary": "Looking for an experienced Chef to oversee kitchen operations, develop menus,\nand ensure high-quality food preparation.",
#     "Key_Responsibilities": "Plan and create menus.\nSupervise kitchen staff.\nEnsure food quality and presentation.\nMaintain kitchen hygiene and safety standards.",
#     "Qualifications": "Culinary degree or equivalent experience.\nProven experience as a Chef.",
#     "Skills": "Creativity and attention to detail.\nStrong leadership and organizational skills."
#   },
#   {
#     "Job_Title": "Engineer",
#     "Job_Summary": "Seeking a qualified Engineer to design, develop, and implement engineering\nsolutions for various projects.",
#     "Key_Responsibilities": "Design and develop engineering projects.\nConduct research and analysis.\nCollaborate with cross-functional teams.\nEnsure compliance with safety and quality standards.",
#     "Qualifications": "Bachelor's degree in Engineering.\nRelevant engineering certifications.",
#     "Skills": "Strong problem-solving and analytical skills.\nProficiency in engineering software and tools."
#   },
#   {
#     "Job_Title": "Accountant",
#     "Job_Summary": "We are looking for a detail-oriented Accountant to manage financial records,\nprepare reports, and ensure compliance with financial regulations.",
#     "Key_Responsibilities": "Prepare and examine financial records.\nEnsure accuracy and compliance with regulations.\nManage budgets and financial planning.\nConduct audits and financial analysis.",
#     "Qualifications": "Bachelor's degree in Accounting or Finance.\nCPA certification is a plus.",
#     "Skills": "Proficiency in accounting software.\nStrong analytical and numerical skills."
#   },
#   {
#     "Job_Title": "Finance Analyst",
#     "Job_Summary": "Seeking a Finance Analyst to assess financial data, prepare reports, and provide\ninsights to support decision-making.",
#     "Key_Responsibilities": "Analyze financial statements and data.\nPrepare financial reports and forecasts.\nMonitor financial performance.\nProvide recommendations for financial improvements.",
#     "Qualifications": "Bachelor's degree in Finance, Economics, or related field.\nExperience in financial analysis.",
#     "Skills": "Strong analytical and problem-solving skills.\nProficiency in financial modeling and Excel."
#   },
#   {
#     "Job_Title": "Fitness Trainer",
#     "Job_Summary": "Looking for a certified Fitness Trainer to develop and implement fitness programs,\nguide clients, and promote healthy lifestyles.",
#     "Key_Responsibilities": "Design personalized fitness programs.\nInstruct and motivate clients.\nMonitor progress and adjust programs as needed.\nEnsure safety during workouts.",
#     "Qualifications": "Certification in fitness training.\nExperience in personal training.",
#     "Skills": "Excellent interpersonal and motivational skills.\nKnowledge of fitness and nutrition principles."
#   },
#   {
#     "Job_Title": "Aviation Technician",
#     "Job_Summary": "Seeking an Aviation Technician to perform maintenance and repairs on aircraft to\nensure safety and compliance.",
#     "Key_Responsibilities": "Inspect and repair aircraft systems.\nPerform routine maintenance checks.\nDocument maintenance activities.\nEnsure compliance with aviation regulations.",
#     "Qualifications": "Certification in aviation maintenance.\nExperience in aircraft maintenance.",
#     "Skills": "Attention to detail and technical proficiency.\nStrong problem-solving skills."
#   },
#   {
#     "Job_Title": "Sales Executive",
#     "Job_Summary": "We are looking for a dynamic Sales Executive to drive sales, build client\nrelationships, and achieve revenue targets.",
#     "Key_Responsibilities": "Identify and pursue sales opportunities.\nDevelop and maintain client relationships.\nPresent products and services to clients.\nAchieve sales targets and objectives.",
#     "Qualifications": "Bachelor's degree in Business, Marketing, or related field.\nProven sales experience.",
#     "Skills": "Excellent communication and negotiation skills.\nAbility to work independently and in a team."
#   },
#   {
#     "Job_Title": "Banking Professional",
#     "Job_Summary": "Seeking a detail-oriented Banking Professional to manage client accounts, process\ntransactions, and provide financial guidance to customers.",
#     "Key_Responsibilities": "Open and close customer accounts.\nProcess deposits, withdrawals, and payments.\nAuthorize and evaluate overdrafts and loans.\nRecommend banking services and products to clients.",
#     "Qualifications": "Bachelor's degree in Finance, Accounting, or related field.\nExperience in banking or financial services.",
#     "Skills": "Strong numerical and analytical skills.\nExcellent customer service and communication abilities."
#   },
#   {
#     "Job_Title": "Healthcare Administrator",
#     "Job_Summary": "Looking for a Healthcare Administrator to oversee medical facility operations,\nensuring efficient and effective delivery of healthcare services.",
#     "Key_Responsibilities": "Manage daily operations of healthcare facilities.\nCoordinate between departments and staff.\nEnsure compliance with healthcare regulations.\nDevelop and implement policies and procedures.",
#     "Qualifications": "Bachelor's degree in Healthcare Administration or related field.\nExperience in healthcare management.",
#     "Skills": "Strong leadership and organizational skills.\nKnowledge of healthcare laws and regulations."
#   },
#   {
#     "Job_Title": "Consultant",
#     "Job_Summary": "Seeking a Consultant to provide expert advice and solutions to improve business\nperformance and efficiency.",
#     "Key_Responsibilities": "Analyze organizational challenges and opportunities.\nDevelop strategic plans and recommendations.\nCollaborate with clients to implement solutions.\nMonitor progress and adjust strategies as needed.",
#     "Qualifications": "Bachelor's degree in Business, Management, or related field.\nProven experience in consulting or advisory roles.",
#     "Skills": "Strong analytical and problem-solving abilities.\nExcellent communication and interpersonal skills."
#   },
#   {
#     "Job_Title": "Construction Worker",
#     "Job_Summary": "Looking for a Construction Worker to perform various tasks on construction sites,\nensuring projects are completed safely and efficiently.",
#     "Key_Responsibilities": "Assist with building and demolition tasks.\nOperate construction equipment and tools.\nFollow safety protocols and guidelines.\nCollaborate with team members and supervisors.",
#     "Qualifications": "High school diploma or equivalent.\nExperience in construction or related fields.",
#     "Skills": "Physical stamina and strength.\nKnowledge of construction methods and materials."
#   },
#   {
#     "Job_Title": "Public Relations Specialist",
#     "Job_Summary": "Seeking a Public Relations Specialist to manage and enhance the public image of\nour organization through strategic communication.",
#     "Key_Responsibilities": "Develop and implement PR strategies.\nWrite and distribute press releases and media content.\nMaintain relationships with media outlets.\nMonitor public opinion and manage crisis communication.",
#     "Qualifications": "Bachelor's degree in Public Relations, Communications, or related field.\nExperience in PR or media relations.",
#     "Skills": "Excellent written and verbal communication skills.\nAbility to manage multiple projects and deadlines."
#   },
#   {
#     "Job_Title": "Human Resources Manager",
#     "Job_Summary": "Looking for a Human Resources Manager to oversee HR functions, including\nrecruitment, employee relations, and compliance with labor laws.",
#     "Key_Responsibilities": "Manage hiring processes and onboarding.\nDevelop HR policies and procedures.\nAddress employee concerns and conflicts.\nEnsure compliance with employment regulations.",
#     "Qualifications": "Bachelor's degree in Human Resources or related field.\nExperience in HR management.",
#     "Skills": "Strong leadership and decision-making abilities.\nKnowledge of HR software and systems."
#   },
#   {
#     "Job_Title": "Designer",
#     "Job_Summary": "Seeking a creative Designer to develop visual concepts and designs for various\nprojects, ensuring alignment with brand identity.",
#     "Key_Responsibilities": "Create designs for digital and print media.\nCollaborate with clients and team members.\nPresent design concepts and revisions.\nStay updated on design trends and tools.",
#     "Qualifications": "Bachelor's degree in Design, Fine Arts, or related field.\nProficiency in design software (e.g., Adobe Creative Suite).",
#     "Skills": "Strong artistic and creative abilities.\nAttention to detail and aesthetic sensibility."
#   },
#   {
#     "Job_Title": "Artist",
#     "Job_Summary": "Looking for an Artist to produce original artworks for various mediums,\ncontributing to the creative vision of our projects.",
#     "Key_Responsibilities": "Create artworks using different materials and techniques.\nCollaborate with clients and creative teams.\nPresent and exhibit artworks.\nContinuously develop artistic skills.",
#     "Qualifications": "Bachelor's degree in Fine Arts or related field.\nPortfolio showcasing artistic works.",
#     "Skills": "Creativity and originality.\nProficiency in various art mediums."
#   },
#   {
#     "Job_Title": "Teacher",
#     "Job_Summary": "Seeking a dedicated Teacher to educate and inspire students, fostering a positive\nand engaging learning environment.",
#     "Key_Responsibilities": "Develop and deliver lesson plans.\nAssess student progress and provide feedback.\nManage classroom behavior and dynamics.\nCollaborate with colleagues and parents.",
#     "Qualifications": "Bachelor's degree in Education or subject-specific field.\nTeaching certification or license.",
#     "Skills": "Strong communication and instructional skills.\nPatience and adaptability."
#   },
#   {
#     "Job_Title": "Apparel Designer",
#     "Job_Summary": "Looking for an Apparel Designer to conceptualize and create clothing designs that\nalign with current fashion trends and brand identity.",
#     "Key_Responsibilities": "Develop sketches and prototypes for garments.\nSelect fabrics and materials.\nCollaborate with production teams.\nMonitor market trends and consumer preferences.",
#     "Qualifications": "Bachelor's degree in Fashion Design or related field.\nExperience in apparel design.",
#     "Skills": "Creativity and fashion sense.\nProficiency in design software and tools."
#   },
#   {
#     "Job_Title": "Digital Media Specialist",
#     "Job_Summary": "Seeking a creative Digital Media Specialist to develop and manage digital content\nacross various platforms, enhancing our online presence and engagement.",
#     "Key_Responsibilities": "Create and manage digital content for websites, social media, and email campaigns.\nDevelop and implement digital marketing strategies.\nAnalyze performance metrics and optimize content accordingly.\nCollaborate with design and marketing teams to align content with brand guidelines.",
#     "Qualifications": "Bachelor's degree in Marketing, Communications, or related field.\nExperience with digital marketing tools and platforms.",
#     "Skills": "Proficiency in content management systems and analytics tools.\nStrong writing and editing skills."
#   },
#   {
#     "Job_Title": "Agricultural Worker",
#     "Job_Summary": "Looking for a dedicated Agricultural Worker to assist in crop cultivation and\nlivestock care, ensuring efficient farm operations.",
#     "Key_Responsibilities": "Plant, cultivate, and harvest crops.\nFeed and care for livestock.\nOperate and maintain farm machinery.\nMonitor crop and animal health.",
#     "Qualifications": "High school diploma or equivalent.\nExperience in farming or related activities.",
#     "Skills": "Physical stamina and strength.\nKnowledge of agricultural practices and machinery."
#   },
#   {
#     "Job_Title": "Automotive Technician",
#     "Job_Summary": "Seeking a skilled Automotive Technician to diagnose, repair, and maintain vehicles,\nensuring optimal performance and safety.",
#     "Key_Responsibilities": "Perform routine maintenance and repairs on vehicles.\nDiagnose mechanical and electrical issues.\nTest vehicle systems and components.\nMaintain accurate records of services performed.",
#     "Qualifications": "Certification from a vocational school or completion of apprenticeship.\nValid driver's license.",
#     "Skills": "Proficiency with diagnostic tools and equipment.\nStrong problem-solving abilities."
#   },
#   {
#     "Job_Title": "BPO Associate",
#     "Job_Summary": "Looking for a BPO Associate to handle customer interactions and support services,\nensuring client satisfaction and efficient operations.",
#     "Key_Responsibilities": "Manage inbound and outbound customer calls.\nProvide product and service information.\nResolve customer complaints and issues.\nDocument customer interactions and transactions.",
#     "Qualifications": "High school diploma or equivalent.\nExperience in customer service or call center environment.",
#     "Skills": "Excellent communication and interpersonal skills.\nAbility to handle multiple tasks efficiently."
#   }
# ]

# %%
len(job_data)
# Out:
# 24

# %%
def extract_job_titles(job_data):
    return [job["Job_Title"] for job in job_data]

job_titles = extract_job_titles(job_data)
print("Job Titles:")
i = 1
for title in job_titles:
    print(i , title)
    i +=1
# Out:
# Job Titles:
# 1 Information Technology (IT) Specialist
# 2 Business Development Manager
# 3 Advocate (Lawyer)
# 4 Chef
# 5 Engineer
# 6 Accountant
# 7 Finance Analyst
# 8 Fitness Trainer
# 9 Aviation Technician
# 10 Sales Executive
# 11 Banking Professional
# 12 Healthcare Administrator
# 13 Consultant
# 14 Construction Worker
# 15 Public Relations Specialist
# 16 Human Resources Manager
# 17 Designer
# 18 Artist
# 19 Teacher
# 20 Apparel Designer
# 21 Digital Media Specialist
# 22 Agricultural Worker
# 23 Automotive Technician
# 24 BPO Associate

# %% [markdown]
# # LLM models

# %%
from langchain.chat_models import ChatOpenAI

llm_llama_4_maver = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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",
    model="meta-llama/llama-4-maverick:free",
    temperature=0.0,
    name="Llama-4-Maverick"
)

llm_llama_4_scot = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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",
    model="meta-llama/llama-4-scout:free",
    temperature=0.0,
    name="Llama-4-Scout"
)

llm_deepseek_R1 = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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",
    model="deepseek/deepseek-r1:free",
    temperature=0.0,
    name="DeepSeek-R1"
)

llm_qwen3_30B = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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",
    model="qwen/qwen3-30b-a3b:free",
    temperature=0.0,
    name="Qwen3-30B-A3B"
)

llm_qwen3_14B = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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",
    model="qwen/qwen3-14b:free",
    temperature=0.0,
    name="Qwen3-14B"
)

llm_qwen3_8B = ChatOpenAI(
    base_url="https://openrouter.ai/api/v1",
    api_key="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",
    model="qwen/qwen3-8b:free",
    temperature=0.0,
    name="Qwen3-8B"
)

# %% [markdown]
# # LangChain

# %%
from langchain.chains import SequentialChain, LLMChain
from langchain.prompts import PromptTemplate

# %%
job_title_prompt = PromptTemplate(
    input_variables=["resume_text" , "job_Titles"],
    template="""
You are an AI recruiter. Based on the following resume text, identify the most appropriate job title this resume fits:

Resume:
{resume_text}

Job Titles:
{job_Titles}

Return only the job title.
"""
)

# %%
Information_Technology_resume = """John Smith
Email: john.smith@example.com | Phone: (123) 456-7890 | Location: New York, NY

Professional Summary:
Detail-oriented IT Specialist with over 5 years of experience managing and supporting enterprise-level networks, systems, and applications. Adept in troubleshooting complex technical issues, implementing cybersecurity protocols, and ensuring optimal performance of IT infrastructure. Known for strong problem-solving skills and ability to deliver solutions under pressure.

Experience:
IT Specialist — XYZ Corporation, New York, NY  
Jan 2020 – Present
- Installed, configured, and maintained Windows and Linux servers across multiple departments.
- Provided Tier 2 and Tier 3 technical support to over 300 employees.
- Monitored system performance and executed preventive maintenance procedures.
- Led migration of legacy systems to Microsoft Azure cloud environment, reducing costs by 20%.
- Enforced cybersecurity measures including multi-factor authentication and endpoint protection.

Technical Support Analyst — TechPro Solutions, Brooklyn, NY  
Jun 2017 – Dec 2019
- Resolved over 50+ weekly support tickets related to software, hardware, and networking issues.
- Assisted in configuring routers, switches, and firewalls in small office environments.
- Developed internal documentation and user guides for troubleshooting common IT problems.

Education:
B.S. in Information Technology — City University of New York  
Graduated: 2017

Certifications:
- CompTIA Security+
- Microsoft Certified: Azure Administrator Associate
- Cisco Certified Network Associate (CCNA)

Skills:
- Operating Systems: Windows, Linux (Ubuntu, CentOS)
- Networking: TCP/IP, DNS, DHCP, VPN
- Cloud Platforms: Microsoft Azure, AWS (basic)
- Tools: Active Directory, PowerShell, VMware, Office 365
- Soft Skills: Troubleshooting, communication, teamwork, documentation
"""

# %%
LLM_modles = [llm_llama_4_maver , llm_llama_4_scot, llm_deepseek_R1, llm_qwen3_30B, llm_qwen3_14B, llm_qwen3_8B]
for modle in LLM_modles:
    job_title_chain = LLMChain(llm=modle, prompt=job_title_prompt)
    result = job_title_chain.run({
    "resume_text": Information_Technology_resume,
    "job_Titles": ", ".join(job_titles)
    })
    print(f"Model: {modle.get_name()} - Job Title: {result}")
# Out:
# Model: Llama-4-Maverick - Job Title: Information Technology (IT) Specialist
# Model: Llama-4-Scout - Job Title: Information Technology (IT) Specialist
# Model: DeepSeek-R1 - Job Title: Information Technology (IT) Specialist
# Model: Qwen3-30B-A3B - Job Title: Information Technology (IT) Specialist
# Model: Qwen3-14B - Job Title: Information Technology (IT) Specialist
# Model: Qwen3-8B - Job Title: Information Technology (IT) Specialist

# %%
Engineer_resume = """Jane Doe
Email: jane.doe@example.com | Phone: (987) 654-3210 | Location: San Francisco, CA

Professional Summary:
Results-driven Engineer with 6+ years of experience in mechanical design, product development, and process optimization. Proven track record in designing cost-effective and reliable engineering solutions for manufacturing and R&D environments. Skilled in CAD tools, FEA simulations, and cross-functional team collaboration.

Experience:
Mechanical Engineer — Innovatech Industries, San Francisco, CA  
Mar 2019 – Present
- Designed and developed mechanical components for industrial automation systems.
- Led prototyping and testing phases to ensure performance and durability.
- Collaborated with electrical and software teams to integrate components into larger systems.
- Reduced manufacturing costs by 15% through material and design optimization.
- Used SolidWorks and AutoCAD to produce 3D models and detailed engineering drawings.

Junior Design Engineer — WestBridge Manufacturing, Oakland, CA  
Aug 2016 – Feb 2019
- Created technical drawings and BOMs for custom machinery.
- Performed tolerance analysis and finite element analysis (FEA) for stress testing.
- Assisted in root-cause analysis for product failures and implemented corrective measures.
- Participated in supplier evaluation and quality inspections.

Education:
B.S. in Mechanical Engineering — University of California, Berkeley  
Graduated: 2016

Certifications:
- Certified SolidWorks Professional (CSWP)
- Six Sigma Green Belt

Skills:
- CAD Tools: SolidWorks, AutoCAD, CATIA
- Simulation: ANSYS, FEA, CFD
- Manufacturing: CNC, injection molding, sheet metal design
- Software: MATLAB, Excel (advanced), Python (basic)
- Soft Skills: Problem-solving, project management, cross-functional teamwork
"""

# %%
LLM_modles = [llm_llama_4_maver , llm_llama_4_scot, llm_deepseek_R1, llm_qwen3_30B, llm_qwen3_14B, llm_qwen3_8B]
for modle in LLM_modles:
    job_title_chain = LLMChain(llm=modle, prompt=job_title_prompt)
    result = job_title_chain.run({
    "resume_text": Engineer_resume,
    "job_Titles": ", ".join(job_titles)
    })
    print(f"Model: {modle.get_name()} - Job Title: {result}")
# Out:
# Model: Llama-4-Maverick - Job Title: Engineer
# Model: Llama-4-Scout - Job Title: Engineer
# Model: DeepSeek-R1 - Job Title: Engineer
# Model: Qwen3-30B-A3B - Job Title: Engineer
# Model: Qwen3-14B - Job Title: Engineer
# Model: Qwen3-8B - Job Title: Engineer
